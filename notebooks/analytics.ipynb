# %% [markdown]
# # Business Sales Analytics Project
#
# This project analyzes retail sales data using PostgreSQL, SQL, Python, and Pandas to generate business insights and KPIs.

# %% [markdown]
# ## Problem Statement
#
# The goal of this project is to analyze sales transactions and identify:
# - top-performing categories
# - best-selling products
# - regional performance
# - customer behavior
# - business KPIs

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
DATABASE_URL = "postgresql://postgres:123456@localhost:5432/sales_analytics"

engine = create_engine(DATABASE_URL)

# %%
query = "SELECT * FROM sales"

df = pd.read_sql(query, engine)

df.head()
# Out:
#   transaction_id transaction_date customer_id customer_gender  \
# 0       T0000001       2024-04-24     C000820           Other
# 1       T0000002       2025-07-12     C002849           Other
# 2       T0000003       2025-06-01     C019727            Male
# 3       T0000004       2025-08-26     C009116            Male
# 4       T0000005       2024-12-10     C003350            Male
#
#   customer_age_group customer_segment product_id   product_name  category  \
# 0              35-44        Returning      P1082      Dumbbells    Sports
# 1              45-54              New      P1087  Running Shoes    Sports
# 2                55+        Returning      P1030       Sneakers  Clothing
# 3              25-34              VIP      P1058      Sunscreen    Beauty
# 4              45-54              New      P1028       Sneakers  Clothing
#
#      brand  quantity  unit_price  discount_pct  sales_amount payment_method  \
# ...

# %% [markdown]
# ## Dataset Overview
#
# The dataset contains:
# - transaction information
# - customer demographics
# - product details
# - regional sales data

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'customer_id', 'customer_gender',
#        'customer_age_group', 'customer_segment', 'product_id', 'product_name',
#        'category', 'brand', 'quantity', 'unit_price', 'discount_pct',
#        'sales_amount', 'payment_method', 'sales_channel', 'region'],
#       dtype='str')

# %% [markdown]
# ## Key Performance Indicators (KPIs)
#
# This section analyzes:
# - total sales
# - average sales
# - category performance
# - regional performance

# %%
total_sales = df["sales_amount"].sum()

round(total_sales, 2)
# Out:
# np.float64(45357054.45)

# %% [markdown]
# ## Category Sales Analysis
#
# This analysis identifies the highest revenue-generating product categories.

# %%
category_sales = (
    df.groupby("category")["sales_amount"]
    .sum()
    .sort_values(ascending=False)
)

category_sales
# Out:
# category
# Beauty         6355718.23
# Books          6005237.69
# Sports         5863370.76
# Electronics    5859686.69
# Home           5655562.80
# Toys           5557562.19
# Groceries      5431536.64
# Clothing       4628379.45
# Name: sales_amount, dtype: float64

# %% [markdown]
# ## Observations
#
# - Electronics category generates the highest sales.
# - Sports products show strong customer demand.
# - Some categories contribute significantly less revenue.

# %% [markdown]
# ## Data Visualization
#
# The following charts help identify business trends, customer behavior, and product performance.

# %%
from IPython.display import Image

Image(filename="../reports/charts/category_sales.png")

# %% [markdown]
# ## Visualization Insights
#
# - Electronics category dominates total revenue.
# - Certain products contribute disproportionately to sales.
# - Regional sales vary significantly across markets.
# - Quantity and sales amount show strong positive correlation.
